# %%
import yfinance as yf
import pandas as pd
from datetime import datetime, timedelta
import os

tickers = ["INTC", "NVDA"]

event_date = datetime(2025,8,18)

start_date = event_date - timedelta(days=30)
end_date = event_date + timedelta(days=30)

raw_data_dir = "../data/raw/"
os.makedirs(raw_data_dir, exist_ok=True)

stock_data = {}

for ticker in tickers:
    df = yf.download(ticker, start=start_date, end=end_date, auto_adjust = True)
    df.reset_index(inplace=True)
    stock_data[ticker] = df

    file_path = os.path.join(raw_data_dir, f"{ticker}_stock_data.csv")
    df.to_csv(file_path, index=False)
    print(f"Saved {ticker} data to {file_path}")

    for ticker, df in stock_data.items():
        print(f"\n{ticker} Data Sample:")
        print(df.head())
# Out:
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# Saved INTC data to ../data/raw/INTC_stock_data.csv
#
# INTC Data Sample:
# Price        Date      Close       High        Low   Open     Volume
# Ticker                  INTC       INTC       INTC   INTC       INTC
# 0      2025-07-21  23.260000  23.830000  23.160000  23.40   61658000
# 1      2025-07-22  23.240000  23.540001  23.080000  23.34   53969800
# 2      2025-07-23  23.490000  23.620001  22.920000  23.26   68711700
# 3      2025-07-24  22.629999  23.580000  22.600000  23.49  131963300
# 4      2025-07-25  20.700001  21.049999  20.360001  20.68  245077700
# Saved NVDA data to ../data/raw/NVDA_stock_data.csv
#
# INTC Data Sample:
# Price        Date      Close       High        Low   Open     Volume
# Ticker                  INTC       INTC       INTC   INTC       INTC
# 0      2025-07-21  23.260000  23.830000  23.160000  23.40   61658000
# 1      2025-07-22  23.240000  23.540001  23.080000  23.34   53969800
# 2      2025-07-23  23.490000  23.620001  22.920000  23.26   68711700
# 3      2025-07-24  22.629999  23.580000  22.600000  23.49  131963300
# 4      2025-07-25  20.700001  21.049999  20.360001  20.68  245077700
#
# NVDA Data Sample:
# Price        Date       Close        High         Low        Open     Volume
# Ticker                   NVDA        NVDA        NVDA        NVDA       NVDA
# 0      2025-07-21  171.370346  173.370233  170.990363  172.740264  123126100
# 1      2025-07-22  167.020584  171.380339  164.570725  171.330339  193114300
# 2      2025-07-23  170.770370  171.250339  167.960531  169.520441  154082200
# 3      2025-07-24  173.730209  173.820201  171.290344  172.430280  128984600
# 4      2025-07-25  173.490219  174.710152  172.950256  173.600214  122316800
