# %%
import yfinance as yf
import pandas as pd
from datetime import datetime, timedelta
import os

tickers = ["INTC", "NVDA"]

event_date = datetime(2025,9,18)

start_date = event_date - timedelta(days=30)
end_date = event_date + timedelta(days=30)

raw_data_dir = "../data/raw/"
os.makedirs(raw_data_dir, exist_ok=True)

stock_data = {}

for ticker in tickers:
    df = yf.download(ticker, start=start_date, end=end_date, auto_adjust = True)
    df.reset_index(inplace=True)
    stock_data[ticker] = df

    file_path = os.path.join(raw_data_dir, f"{ticker}_stock_data.csv")
    df.to_csv(file_path, index=False)
    print(f"Saved {ticker} data to {file_path}")

    for ticker, df in stock_data.items():
        print(f"\n{ticker} Data Sample:")
        print(df.head())
# Out:
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# Saved INTC data to ../data/raw/INTC_stock_data.csv
#
# INTC Data Sample:
# Price        Date      Close       High        Low       Open     Volume
# Ticker                  INTC       INTC       INTC       INTC       INTC
# 0      2025-08-19  25.309999  26.530001  24.940001  24.940001  297659200
# 1      2025-08-20  23.540001  24.930000  23.330000  24.900000  161149400
# 2      2025-08-21  23.500000  23.570000  22.780001  23.530001   97718300
# 3      2025-08-22  24.799999  25.230000  23.650000  23.650000  200266800
# 4      2025-08-25  24.549999  25.879999  24.440001  25.500000  156825600
# Saved NVDA data to ../data/raw/NVDA_stock_data.csv
#
# INTC Data Sample:
# Price        Date      Close       High        Low       Open     Volume
# Ticker                  INTC       INTC       INTC       INTC       INTC
# 0      2025-08-19  25.309999  26.530001  24.940001  24.940001  297659200
# 1      2025-08-20  23.540001  24.930000  23.330000  24.900000  161149400
# 2      2025-08-21  23.500000  23.570000  22.780001  23.530001   97718300
# 3      2025-08-22  24.799999  25.230000  23.650000  23.650000  200266800
# 4      2025-08-25  24.549999  25.879999  24.440001  25.500000  156825600
#
# NVDA Data Sample:
# Price        Date       Close        High         Low        Open     Volume
# Ticker                   NVDA        NVDA        NVDA        NVDA       NVDA
# 0      2025-08-19  175.630096  182.489710  175.480111  182.419707  185229200
# 1      2025-08-20  175.390106  175.990078  168.790487  175.160123  215142700
# 2      2025-08-21  174.970123  176.890013  173.800191  174.840141  140040900
# 3      2025-08-22  177.979965  178.579922  171.190340  172.600264  172789400
# 4      2025-08-25  179.799866  181.899753  176.560058  178.339957  163012800
