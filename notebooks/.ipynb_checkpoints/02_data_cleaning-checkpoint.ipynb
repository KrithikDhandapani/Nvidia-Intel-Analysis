# %%
# Import data sets

import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

intel = pd.read_csv("../data/raw/INTC_stock_data.csv", parse_dates=["Date"], index_col="Date")
nvidia = pd.read_csv("../data/raw/NVDA_stock_data.csv", parse_dates=["Date"], index_col="Date")

print("Intel data:", intel.shape)
print("NVIDIA data:", nvidia.shape)
print(intel.head())
# Out:
# Intel data: (32, 5)
# NVIDIA data: (32, 5)
#                          Close                High                 Low  \
# Date
# NaT                       INTC                INTC                INTC
# 2025-08-19  25.309999465942383  26.530000686645508  24.940000534057617
# 2025-08-20  23.540000915527344   24.93000030517578  23.329999923706055
# 2025-08-21                23.5   23.56999969482422  22.780000686645508
# 2025-08-22  24.799999237060547  25.229999542236328  23.649999618530273
#
#                           Open     Volume
# Date
# NaT                       INTC       INTC
# 2025-08-19  24.940000534057617  297659200
# 2025-08-20  24.899999618530273  161149400
# 2025-08-21  23.530000686645508   97718300
# 2025-08-22  23.649999618530273  200266800

# %%
print("Missing values (Intel):")
print(intel.isna().sum())

print("Missing values (NVIDIA):")
print(nvidia.isna().sum())
# Out:
# Missing values (Intel):
# Close     0
# High      0
# Low       0
# Open      0
# Volume    0
# dtype: int64
# Missing values (NVIDIA):
# Close     0
# High      0
# Low       0
# Open      0
# Volume    0
# dtype: int64

# %%
event_date = pd.to_datetime("2025-09-17")

intel["EventWindow"] = intel.index.map(lambda x: "Before" if x < event_date else "After")
nvidia["EventWindow"] = nvidia.index.map(lambda x: "Before" if x < event_date else "After")

# %%
# Intel stock price analysis around NVIDIA Investment

intel["Close"] = pd.to_numeric(intel["Close"], errors="coerce")


intel = intel.dropna(subset=["Close"])


intel_min, intel_max = intel["Close"].min(), intel["Close"].max()

# Stretch/scale data to nearest 5-step axis
scaled_min = 5 * np.floor(intel_min / 5)
scaled_max = 5 * np.ceil(intel_max / 5)

# Create scaling function
def rescale(value, old_min, old_max, new_min, new_max):
    return (value - old_min) / (old_max - old_min) * (new_max - new_min) + new_min

intel_scaled = rescale(intel["Close"], intel_min, intel_max, scaled_min, scaled_max)

# Plot
plt.figure(figsize=(12,6))
plt.plot(intel.index, intel_scaled, label="Intel Close Price (Rescaled)", color="blue")
plt.axvline(event_date, color="red", linestyle="--", label="NVIDIA Investment")

# Set y-axis ticks in increments of 5
plt.yticks(np.arange(scaled_min, scaled_max+5, 5))

plt.title("Intel Stock Price")
plt.xlabel("Date")
plt.ylabel("Price (USD)")
plt.legend()
plt.show()

# %%
# Intel vs competitors stock price comparison

import matplotlib.pyplot as plt
import numpy as np
import yfinance as yf
import pandas as pd
from datetime import datetime, timedelta


event_date = datetime(2025, 9, 18)  


start_date = event_date - timedelta(days=30)
end_date = event_date + timedelta(days=30)


competitors = ["NVDA", "AMD", "TSM", "QCOM"]
all_tickers = ["INTC"] + competitors


data = yf.download(all_tickers, start=start_date, end=end_date)["Close"]


base_prices = data.loc[event_date.strftime("%Y-%m-%d")]
normalized = (data / base_prices) * 100


plt.figure(figsize=(12,6))
for ticker in all_tickers:
    if ticker == "INTC":
        plt.plot(normalized.index, normalized[ticker], label=ticker, linewidth=2, color="blue")
    else:
        plt.plot(normalized.index, normalized[ticker], label=ticker, alpha=0.7)

plt.axvline(event_date, color="red", linestyle="--", label="NVIDIA Investment")
plt.title("Intel vs Competitors: Stock Price Normalized at Event Date")
plt.xlabel("Date")
plt.ylabel("Normalized Price (100 = Event Date)")
plt.legend()
plt.grid(True)
plt.show()
# Out:
# C:\Users\krith\AppData\Local\Temp\ipykernel_16688\2068549893.py:19: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   data = yf.download(all_tickers, start=start_date, end=end_date)["Close"]
# [*********************100%***********************]  5 of 5 completed

# %%
# Analyzing trading volume and interest around NVIDIA investment event

import matplotlib.pyplot as plt
import yfinance as yf
import pandas as pd
from datetime import datetime, timedelta
import matplotlib.dates as mdates

# Parameters - Using a historical date (example: Sept 2024)
event_date = datetime(2025, 9, 18)  

start_date = pd.to_datetime(event_date) - timedelta(days=30)
end_date   = pd.to_datetime(event_date) + timedelta(days=30)

# Download Intel stock data
intel_data = yf.download("INTC", start=start_date, end=end_date, auto_adjust=True)

# Flatten MultiIndex columns if present
if isinstance(intel_data.columns, pd.MultiIndex):
    intel_data.columns = intel_data.columns.get_level_values(0)

# Check if we have data
if intel_data.empty:
    print("No data retrieved. Check your date range.")
else:
    print(f"Retrieved {len(intel_data)} days of data")
    print(f"Date range: {intel_data.index[0]} to {intel_data.index[-1]}")

# Convert index to matplotlib date numbers
dates = mdates.date2num(intel_data.index.to_pydatetime())

# Convert Volume to numpy array and handle the division
volume_millions = intel_data["Volume"].values / 1e6

# Plot
fig, ax1 = plt.subplots(figsize=(12,6))

# Intel close price line
ax1.plot(intel_data.index, intel_data["Close"], color="blue", label="Close Price", linewidth=2, zorder=3)
ax1.set_xlabel("Date")
ax1.set_ylabel("Price (USD)", color="blue")
ax1.tick_params(axis="y", labelcolor="blue")
ax1.grid(True, alpha=0.3)

# Volume bars on secondary axis
ax2 = ax1.twinx()
bar_width = 0.8  # in "days" since dates are converted to floats internally
ax2.bar(dates, volume_millions, width=bar_width, 
        color="gray", alpha=0.3, label="Volume (Millions)", zorder=1)
ax2.set_ylabel("Volume (Millions)", color="gray")
ax2.tick_params(axis="y", labelcolor="gray")

# Vertical line for event
ax1.axvline(pd.to_datetime(event_date), color="red", linestyle="--", linewidth=2, label="Event Date", zorder=4)

# Format x-axis nicely
ax1.xaxis.set_major_formatter(mdates.DateFormatter("%b %d"))
fig.autofmt_xdate()

plt.title("Intel Stock Price & Trading Volume Around Event Date")
fig.legend(loc="upper left", bbox_to_anchor=(0.1,0.9))
plt.tight_layout()
plt.show()
# Out:
# [*********************100%***********************]  1 of 1 completed
# Retrieved 33 days of data
# Date range: 2025-08-19 00:00:00 to 2025-10-03 00:00:00

# %%
# Creating Intel_competitor_benchmark.csv file

import pandas as pd
import yfinance as yf
from datetime import datetime, timedelta

event_date = datetime(2025,9,18)
start_date = event_date - timedelta(days=30)
end_date = event_date + timedelta(days=13)

tickers = ["INTC", "AMD", "TSM", "QCOM"]

data = yf.download(tickers, start=start_date, end=end_date)["Close"]
daily_returns = data.pct_change() * 100
industry_avg = daily_returns.drop(columns="INTC").mean(axis=1)
abnormal_return = daily_returns["INTC"] - industry_avg

benchmark_df = pd.DataFrame({
    "Date" : daily_returns.index, 
    "Intel_Returns" : daily_returns["INTC"],
    "Industry_Avg_Return" : industry_avg,
    "Intel_Abnormal_Return" : abnormal_return
})

benchmark_df.to_csv("intel_competitor_benchmark.csv", index=False)

benchmark_df.head()
# Out:
# C:\Users\krith\AppData\Local\Temp\ipykernel_19244\136301734.py:11: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   data = yf.download(tickers, start=start_date, end=end_date)["Close"]
# [*********************100%***********************]  4 of 4 completed
#                  Date  Intel_Returns  Industry_Avg_Return  \
# Date
# 2025-08-19 2025-08-19            NaN                  NaN
# 2025-08-20 2025-08-20      -6.993278            -1.030298
# 2025-08-21 2025-08-21      -0.169927            -0.766751
# 2025-08-22 2025-08-22       5.531912             2.493667
# 2025-08-25 2025-08-25      -1.008065            -0.837709
#
#             Intel_Abnormal_Return
# Date
# 2025-08-19                    NaN
# 2025-08-20              -5.962980
# 2025-08-21               0.596824
# 2025-08-22               3.038245
# 2025-08-25              -0.170356

# %%
# Step 4 : Percent Change and abnormal returns/ creating intel_abnormal_returns.csv
import matplotlib.pyplot as plt

pct_change = data.pct_change() * 100
cum_returns = (1 + pct_change/100).cumprod() - 1
competitors = ["AMD", "TSM", "QCOM"]
benchmark = pct_change[competitors].mean(axis=1)
abnormal_returns = pct_change["INTC"] - benchmark

output = pd.DataFrame({

    "Date" : pct_change.index,
    "INTC_pct_change" : pct_change["INTC"],
        "Benchmark_pct_change" : benchmark,
        "Abnormal_return" : abnormal_returns,
        "INTC_cum_return" : cum_returns["INTC"],
         "AMD_cum_return" : cum_returns["AMD"],
         "TSM_cum_return" : cum_returns["TSM"],
         "QCOM_cum_return" : cum_returns["QCOM"]
})
output.to_csv("intel_abnormal_returns.csv", index=False)

plt.figure(figsize=(12,6))

for ticker in ["INTC", "AMD", "TSM", "QCOM"]:
    plt.plot(cum_returns.index, cum_returns[ticker], label=ticker)

plt.axvline(event_date, color="red", linestyle="--", label="NVIDIA Investment")
plt.title("Cumulative Returns : Intel vs Competitors")
plt.ylabel("Cumulative Return")
plt.xlabel("Date")
plt.legend()
plt.grid(True)
plt.show()

plt.figure(figsize=(12,6))
plt.bar(abnormal_returns.index, abnormal_returns, color="orange", alpha = 0.6)
plt.axvline(event_date, color="red", linestyle="--", label="Event Date")
plt.title("Intel Abnormal Daily Returns vs Competitors")
plt.ylabel("Abnormal Return (%)")
plt.xlabel("Date")
plt.legend()
plt.show()

# %%
# Merged Preview

import pandas as pd
import yfinance as yf
from datetime import datetime, timedelta

tickers = ["INTC", "AMD", "TSM", "QCOM"]
start_date = "2025-09-01"
end_date = "2025-10-01"

data = yf.download(tickers, start=start_date, end=end_date)["Close"]

output = pd.read_csv("intel_competitor_benchmark.csv")


output['Date'] = pd.to_datetime(output['Date'])


if 'Date' in output.columns and output.index.name == 'Date':
    output = output.drop(columns=['Date'])


output = output.reset_index(drop=True)


output = output.loc[:, ~output.columns.duplicated()]


data_reset = data.reset_index()


merged = pd.merge(
    data_reset.melt(id_vars="Date", var_name="Ticker", value_name="Close"),
    output,
    on="Date",
    how="inner"
)

print(merged.head())
# Out:
# C:\Users\krith\AppData\Local\Temp\ipykernel_13108\2722807418.py:11: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   data = yf.download(tickers, start=start_date, end=end_date)["Close"]
# [*********************100%***********************]  4 of 4 completed
#         Date Ticker       Close  Intel_Returns  Industry_Avg_Return  \
# 0 2025-09-02    AMD  162.320007      -0.574954            -0.826008
# 1 2025-09-03    AMD  162.130005      -0.867406             0.083927
# 2 2025-09-04    AMD  161.789993       2.541669             1.188028
# 3 2025-09-05    AMD  151.139999      -0.487610            -1.004989
# 4 2025-09-08    AMD  151.410004      -0.040834             0.660612
#
#    Intel_Abnormal_Return
# 0               0.251054
# 1              -0.951334
# 2               1.353642
# 3               0.517379
# 4              -0.701446

# %%
# Percentage change comparison chart

import matplotlib.pyplot as plt

returns = merged.pivot(index="Date", columns="Ticker", values="Close")
returns = (returns / returns.iloc[0] - 1) * 100

event_date = pd.to_datetime("2025-09-18")
plt.figure(figsize=(12,6))
for ticker in returns.columns:
    plt.plot(returns.index, returns[ticker], label=ticker)

plt.axvline(event_date, color="red", linestyle="--", label = "NVIDIA Investment")
plt.title("Intel vs Competitors - % Change Around NVIDIA Investment")
plt.xlabel("Date")
plt.ylabel("% Change in stock price")
plt.legend()
plt.grid(True)

plt.axvspan(event_date - pd.Timedelta(7), event_date + pd.Timedelta(7), color="gray", alpha = 0.1, label="Event Window")
plt.show()

# %%
import matplotlib.pyplot as plt

daily_returns = merged.pivot(index="Date", columns="Ticker", values="Close").pct_change() * 100
competitors = ["AMD", "TSM", "QCOM"]
daily_returns["Industry_Avg"] = daily_returns[competitors].mean(axis=1)
daily_returns["Intel_Abnormal"] = daily_returns["INTC"] - daily_returns["Industry_Avg"]
daily_returns["Intel_CAR"] = daily_returns["Intel_Abnormal"].cumsum()
daily_returns.tail()
# Out:
# Ticker           AMD      INTC      QCOM       TSM  Industry_Avg  \
# Date
# 2025-09-24 -0.012423  6.407632  2.371264 -0.707439      0.550467
# 2025-09-25  0.242416  8.872525 -2.229911 -1.442766     -1.143420
# 2025-09-26 -1.122340  4.442478 -0.282883 -1.192806     -0.866010
# 2025-09-29  1.191518 -2.873241 -2.304961 -0.047547     -0.386997
# 2025-09-30  0.266480 -2.697217  0.641257  2.217911      1.041883
#
# Ticker      Intel_Abnormal  Intel_CAR
# Date
# 2025-09-24        5.857164  18.128658
# 2025-09-25       10.015946  28.144604
# 2025-09-26        5.308488  33.453091
# 2025-09-29       -2.486244  30.966848
# 2025-09-30       -3.739099  27.227748

# %%
# Visualize Abnormal Return Behavior
import matplotlib.pyplot as plt

plt.figure(figsize=(12,6))
plt.plot(daily_returns.index, daily_returns["Intel_CAR"], color="blue", label="Intel's Cumulative Abnormal Return")
plt.axvline(pd.to_datetime("2025-09-17"), color="red", linestyle="--", label="NVIDIA Investment")
plt.title("Intel's Cumulative Abnormal Returns vs Industry")
plt.xlabel("Date")
plt.ylabel("Cumulative Abnormal Return (%)")
plt.legend()
plt.grid(True)
plt.show()

# %%
daily_returns.reset_index().to_csv("intel_event_study_daily_returns.csv", index=False)
merged.to_csv("intel_event_study_full_dataset.csv", index=False)

print("Files saved: ")
print("- intel_eevent_study_daily_returns.csv")
print("- intel_event_study_full_datseete.csv")
# Out:
# Files saved:
# - intel_eevent_study_daily_returns.csv
# - intel_event_study_full_datseete.csv

# %%
pre_event = daily_returns.loc[: "2025-09-17", "Intel_Abnormal"]
post_event = daily_returns.loc["2025-09-18", "Intel_Abnormal"]

print("Intel Abnormal Returns Summary : ")
print(f"Average pre-event abnormal return: {pre_event.mean():0.4f}")
print(f"Average post-event abnormal return: {post_event.mean():0.4f}")
print(f"Total CAR over period: {daily_returns['Intel_CAR'].iloc[-1]:0.4f}")
# Out:
# Intel Abnormal Returns Summary :
# Average pre-event abnormal return: -0.2539
# Average post-event abnormal return: 21.7099
# Total CAR over period: 27.2277
